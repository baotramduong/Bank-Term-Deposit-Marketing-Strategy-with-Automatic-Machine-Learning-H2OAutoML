# %%
import pandas as pd
pd.options.display.max_rows = 999
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %% [markdown]
# # Exploratory Data Analysis

# %%
#load data
xls = pd.ExcelFile('bank_term_deposit_marketing_analysis.xlsx')

# %%
#check out all the sheets
xls.sheet_names
# Out:
# ['PROCEDURE',
#  'DATA DESCRIPTION',
#  'Step 1 - Collect Information',
#  'CLIENT_INFO',
#  'LOAN_HISTORY',
#  'MARKETING HISTORY',
#  'SUBSCRIPTION HISTORY',
#  'Step 2 - Merge Information',
#  'CLIENT_MERGE',
#  'Step 3 - Marketing Analysis',
#  'DAILY RANGE',
#  'JOB ANALYSIS',
#  'Sheet3']

# %%
#select only sheets that we want
#create seperate dataframe for each sheet
client_info = pd.read_excel(xls, 'CLIENT_INFO')
loan_history = pd.read_excel(xls, 'LOAN_HISTORY')
marketing_history = pd.read_excel(xls, 'MARKETING HISTORY')
subscription_history = pd.read_excel(xls, 'SUBSCRIPTION HISTORY')

# %%
#preview
client_info.head()
# Out:
#      ID  AGE           JOB  MARITAL  EDUCATION
# 0  2836   58    management  married   tertiary
# 1  2837   44    technician   single  secondary
# 2  2838   33  entrepreneur  married  secondary
# 3  2839   47   blue-collar  married    unknown
# 4  2840   33       unknown   single    unknown

# %%
client_info['AGE'].describe()
# Out:
# count    45211.000000
# mean        40.936210
# std         10.618762
# min         18.000000
# 25%         33.000000
# 50%         39.000000
# 75%         48.000000
# max         95.000000
# Name: AGE, dtype: float64

# %%
client_info['JOB'].value_counts()
# Out:
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: JOB, dtype: int64

# %%
client_info['MARITAL'].value_counts()
# Out:
# married     27214
# single      12790
# divorced     5207
# Name: MARITAL, dtype: int64

# %%
client_info['EDUCATION'].value_counts()
# Out:
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: EDUCATION, dtype: int64

# %%
#preview
loan_history.head()
# Out:
#      ID DEFAULT  BALANCE HOUSING LOAN
# 0  2836      no     2143     yes   no
# 1  2837      no       29     yes   no
# 2  2838      no        2     yes  yes
# 3  2839      no     1506     yes   no
# 4  2840      no        1      no   no

# %%
loan_history['DEFAULT'].value_counts()
# Out:
# no     44396
# yes      815
# Name: DEFAULT, dtype: int64

# %%
loan_history['BALANCE'].describe()
# Out:
# count     45211.000000
# mean       1362.272058
# std        3044.765829
# min       -8019.000000
# 25%          72.000000
# 50%         448.000000
# 75%        1428.000000
# max      102127.000000
# Name: BALANCE, dtype: float64

# %%
loan_history['HOUSING'].value_counts()
# Out:
# yes    25130
# no     20081
# Name: HOUSING, dtype: int64

# %%
loan_history['LOAN'].value_counts()
# Out:
# no     37967
# yes     7244
# Name: LOAN, dtype: int64

# %%
#preview
marketing_history.head()
# Out:
#      ID  CONTACT  DAY MONTH  DURATION  CAMPAIGN  PDAYS  PREVIOUS POUTCOME
# 0  2836  unknown    5   may       261         1     -1         0  unknown
# 1  2837  unknown    5   may       151         1     -1         0  unknown
# 2  2838  unknown    5   may        76         1     -1         0  unknown
# 3  2839  unknown    5   may        92         1     -1         0  unknown
# 4  2840  unknown    5   may       198         1     -1         0  unknown

# %%
marketing_history['CONTACT'].value_counts()
# Out:
# cellular     29285
# unknown      13020
# telephone     2906
# Name: CONTACT, dtype: int64

# %%
marketing_history['DAY'].value_counts()
# Out:
# 20    2752
# 18    2308
# 21    2026
# 17    1939
# 6     1932
# 5     1910
# 14    1848
# 8     1842
# 28    1830
# 7     1817
# 19    1757
# 29    1745
# 15    1703
# 12    1603
# 13    1585
# 30    1566
# 9     1561
# 11    1479
# 4     1445
# 16    1415
# 2     1293
# 27    1121
# 3     1079
# 26    1035
# 23     939
# 22     905
# 25     840
# 31     643
# 10     524
# 24     447
# 1      322
# Name: DAY, dtype: int64

# %%
marketing_history['MONTH'].value_counts()
# Out:
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: MONTH, dtype: int64

# %%
marketing_history['DURATION'].value_counts()
# Out:
# 124     188
# 90      184
# 89      177
# 122     175
# 104     175
#        ...
# 2150      1
# 1970      1
# 1906      1
# 1842      1
# 2015      1
# Name: DURATION, Length: 1573, dtype: int64

# %%
marketing_history['CAMPAIGN'].value_counts()
# Out:
# 1     17544
# 2     12505
# 3      5521
# 4      3522
# 5      1764
# 6      1291
# 7       735
# 8       540
# 9       327
# 10      266
# 11      201
# 12      155
# 13      133
# 14       93
# 15       84
# 16       79
# 17       69
# 18       51
# 19       44
# 20       43
# 21       35
# 22       23
# 23       22
# 25       22
# 24       20
# 28       16
# 29       16
# 26       13
# 31       12
# 27       10
# 32        9
# 30        8
# 33        6
# 34        5
# 36        4
# 35        4
# 43        3
# 38        3
# 41        2
# 50        2
# 37        2
# 51        1
# 55        1
# 46        1
# 58        1
# 44        1
# 39        1
# 63        1
# Name: CAMPAIGN, dtype: int64

# %%
marketing_history['PDAYS'].value_counts().head()
# Out:
# -1      36954
#  182      167
#  92       147
#  183      126
#  91       126
# Name: PDAYS, dtype: int64

# %%
marketing_history['PREVIOUS'].value_counts()
# Out:
# 0      36954
# 1       2772
# 2       2106
# 3       1142
# 4        714
# 5        459
# 6        277
# 7        205
# 8        129
# 9         92
# 10        67
# 11        65
# 12        44
# 13        38
# 15        20
# 14        19
# 17        15
# 16        13
# 19        11
# 23         8
# 20         8
# 22         6
# 18         6
# 24         5
# 27         5
# 29         4
# 25         4
# 21         4
# 30         3
# 28         2
# 26         2
# 37         2
# 38         2
# 55         1
# 40         1
# 35         1
# 58         1
# 51         1
# 41         1
# 32         1
# 275        1
# Name: PREVIOUS, dtype: int64

# %%
marketing_history['POUTCOME'].value_counts()
# Out:
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: POUTCOME, dtype: int64

# %%
#preview
subscription_history.head()

#no = client did not enroll
#yes = client enrolled
#binary classification problem
# Out:
#      ID TERM_DEPOSIT
# 0  2836           no
# 1  2837           no
# 2  2838           no
# 3  2839           no
# 4  2840           no

# %%
subscription_history['TERM_DEPOSIT'].value_counts()
# Out:
# no     39922
# yes     5289
# Name: TERM_DEPOSIT, dtype: int64

# %%
#combine dataframe
df = pd.merge(client_info, loan_history, on=['ID'])
df = pd.merge(df, marketing_history, on=['ID'])
df = pd.merge(df, subscription_history, on=['ID'])

#preview
df.head()
# Out:
#      ID  AGE           JOB  MARITAL  ... PDAYS PREVIOUS  POUTCOME TERM_DEPOSIT
# 0  2836   58    management  married  ...    -1        0   unknown           no
# 1  2837   44    technician   single  ...    -1        0   unknown           no
# 2  2838   33  entrepreneur  married  ...    -1        0   unknown           no
# 3  2839   47   blue-collar  married  ...    -1        0   unknown           no
# 4  2840   33       unknown   single  ...    -1        0   unknown           no
#
# [5 rows x 18 columns]

# %%
#drop 'ID' since it is not predictive
df = df.drop(columns=['ID'], axis=1)
df.head()
# Out:
#    AGE           JOB  MARITAL  EDUCATION  ... PDAYS  PREVIOUS POUTCOME TERM_DEPOSIT
# 0   58    management  married   tertiary  ...    -1         0  unknown           no
# 1   44    technician   single  secondary  ...    -1         0  unknown           no
# 2   33  entrepreneur  married  secondary  ...    -1         0  unknown           no
# 3   47   blue-collar  married    unknown  ...    -1         0  unknown           no
# 4   33       unknown   single    unknown  ...    -1         0  unknown           no
#
# [5 rows x 17 columns]

# %%
#info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AGE           45211 non-null  int64
#  1   JOB           45211 non-null  object
#  2   MARITAL       45211 non-null  object
#  3   EDUCATION     45211 non-null  object
#  4   DEFAULT       45211 non-null  object
#  5   BALANCE       45211 non-null  int64
#  6   HOUSING       45211 non-null  object
#  7   LOAN          45211 non-null  object
#  8   CONTACT       45211 non-null  object
#  9   DAY           45211 non-null  int64
#  10  MONTH         45211 non-null  object
#  11  DURATION      45211 non-null  int64
#  12  CAMPAIGN      45211 non-null  int64
#  13  PDAYS         45211 non-null  int64
#  14  PREVIOUS      45211 non-null  int64
#  15  POUTCOME      45211 non-null  object
#  16  TERM_DEPOSIT  45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 6.2+ MB

# %%
plt.figure(figsize = (30, 10))
sns.countplot(x="AGE", hue='TERM_DEPOSIT', data=df)
plt.xticks(fontsize=10);

# %%
plt.figure(figsize = (15, 5))
sns.countplot(x="JOB", hue='TERM_DEPOSIT', data=df)
plt.xticks(rotation = 45);

# %%
plt.figure(figsize = (15, 5))
sns.countplot(x="MARITAL", hue='TERM_DEPOSIT', data=df);

# %%
plt.figure(figsize = (15, 5))
sns.countplot(x="EDUCATION", hue='TERM_DEPOSIT', data=df);

# %%
plt.figure(figsize = (15, 5))
sns.countplot(x="DEFAULT", hue='TERM_DEPOSIT', data=df);

# %%
plt.figure(figsize = (15, 5))
sns.countplot(x="HOUSING", hue='TERM_DEPOSIT', data=df);

# %%
plt.figure(figsize = (15, 5))
sns.countplot(x="LOAN", hue='TERM_DEPOSIT', data=df);

# %%
plt.figure(figsize = (15, 5))
sns.countplot(x="CONTACT", hue='TERM_DEPOSIT', data=df);

# %%
plt.figure(figsize = (15, 5))
sns.countplot(x="DAY", hue='TERM_DEPOSIT', data=df);

# %%
plt.figure(figsize = (15, 5))
sns.countplot(x="MONTH", hue='TERM_DEPOSIT', data=df);

# %%
plt.figure(figsize = (15, 5))
sns.countplot(x="DURATION", hue='TERM_DEPOSIT', data=df);

# %%
plt.figure(figsize = (15, 5))
sns.countplot(x="CAMPAIGN", hue='TERM_DEPOSIT', data=df);

# %%
plt.figure(figsize = (15, 5))
sns.countplot(x="PDAYS", hue='TERM_DEPOSIT', data=df);

# %%
plt.figure(figsize = (15, 5))
sns.countplot(x="PREVIOUS", hue='TERM_DEPOSIT', data=df);

# %%
plt.figure(figsize = (15, 5))
sns.countplot(x="POUTCOME", hue='TERM_DEPOSIT', data=df);

# %% [markdown]
# # Data Prep & Start H2O

# %%
#start H2O cluster
! pip install h2o
import h2o

#initialize
h2o.init()
# Out:
# Collecting h2o
#   Downloading h2o-3.34.0.1.tar.gz (175.8 MB)
#      |████████████████████████████████| 175.8 MB 33 kB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from h2o) (2.23.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from h2o) (0.8.9)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from h2o) (0.16.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->h2o) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->h2o) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->h2o) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->h2o) (3.0.4)
# Building wheels for collected packages: h2o
#   Building wheel for h2o (setup.py) ... done
#   Created wheel for h2o: filename=h2o-3.34.0.1-py2.py3-none-any.whl size=175823552 sha256=bd58b3ee3ee43041a446967354cc739755e6080499844dc27632470c93693d25
#   Stored in directory: /root/.cache/pip/wheels/5c/7b/60/014a2b6d009793271276a9a41cb954659c8f23b8823ca21625
# Successfully built h2o
# Installing collected packages: h2o
# Successfully installed h2o-3.34.0.1
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.11" 2021-04-20; OpenJDK Runtime Environment (build 11.0.11+9-Ubuntu-0ubuntu2.18.04); OpenJDK 64-Bit Server VM (build 11.0.11+9-Ubuntu-0ubuntu2.18.04, mixed mode, sharing)
#   Starting server from /usr/local/lib/python3.7/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmp46vln3zc
#   JVM stdout: /tmp/tmp46vln3zc/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmp46vln3zc/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         02 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.34.0.1
# H2O_cluster_version_age:    17 days
# H2O_cluster_name:           H2O_from_python_unknownUser_tofv6u
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.172 Gb
# H2O_cluster_total_cores:    2
# H2O_cluster_allowed_cores:  2
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.7.12 final
# --------------------------  ------------------------------------------------------------------

# %%
#convert pandas df into h2o frame
h2o_df = h2o.H2OFrame(df)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
# <tr><td>7      </td><td>42.0              </td><td>entrepreneur</td><td>divorced </td><td>tertiary   </td><td>yes      </td><td>2.0               </td><td>yes      </td><td>no    </td><td>unknown  </td><td>5.0               </td><td>may    </td><td>380.0             </td><td>1.0               </td><td>-1.0              </td><td>0.0               </td><td>unknown   </td><td>no            </td></tr>
# <tr><td>8      </td><td>58.0              </td><td>retired     </td><td>married  </td><td>primary    </td><td>no       </td><td>121.0             </td><td>yes      </td><td>no    </td><td>unknown  </td><td>5.0               </td><td>may    </td><td>50.0              </td><td>1.0               </td><td>-1.0              </td><td>0.0               </td><td>unknown   </td><td>no            </td></tr>
# <tr><td>9      </td><td>43.0              </td><td>technician  </td><td>single   </td><td>secondary  </td><td>no       </td><td>593.0             </td><td>yes      </td><td>no    </td><td>unknown  </td><td>5.0               </td><td>may    </td><td>55.0              </td><td>1.0               </td><td>-1.0              </td><td>0.0               </td><td>unknown   </td><td>no            </td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## Train Test Split

# %%
#split train and test sets
train, test = h2o_df.split_frame(ratios=[.75])

#define X and y
X = train.columns
y = 'TERM_DEPOSIT'
X.remove(y)

# %%
X
# Out:
# ['AGE',
#  'JOB',
#  'MARITAL',
#  'EDUCATION',
#  'DEFAULT',
#  'BALANCE',
#  'HOUSING',
#  'LOAN',
#  'CONTACT',
#  'DAY',
#  'MONTH',
#  'DURATION',
#  'CAMPAIGN',
#  'PDAYS',
#  'PREVIOUS',
#  'POUTCOME']

# %%
y
# Out:
# 'TERM_DEPOSIT'

# %% [markdown]
# # Run H2O AutoML

# %%
#check class distribution
df.TERM_DEPOSIT.value_counts()
# Out:
# no     39922
# yes     5289
# Name: TERM_DEPOSIT, dtype: int64

# %%
from h2o.automl import H2OAutoML

#initialize
aml = H2OAutoML(max_runtime_secs=3600,   #keep runtime at max
                balance_classes=True,
                stopping_metric='logloss',
                seed=1,
                project_name='Final')

# %%
#train
# %time 
aml.train(x=X, 
          y=y,
          training_frame=train)
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.15 µs
# AutoML progress: |███████████████████████████████████████████████████████████████| (done) 100%
# Model Details
# =============
# H2OStackedEnsembleEstimator :  Stacked Ensemble
# Model Key:  StackedEnsemble_AllModels_3_AutoML_1_20211001_200203
#
# No model summary for this model
#
# ModelMetricsBinomialGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.0352567959965488
# RMSE: 0.18776793122508648
# LogLoss: 0.12265871556826867
# Null degrees of freedom: 10064
# Residual degrees of freedom: 10039
# Null deviance: 7250.489028251507
# Residual deviance: 2469.1199443892483
# AIC: 2521.1199443892483
# AUC: 0.9838151034955434
# AUCPR: 0.9060464714993279
# Gini: 0.9676302069910867
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.4952161118412199:
#               no     yes   Error              Rate
# 0     no  8728.0   163.0  0.0183    (163.0/8891.0)
# 1    yes   257.0   917.0  0.2189    (257.0/1174.0)
# 2  Total  8985.0  1080.0  0.0417   (420.0/10065.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold        value    idx
# 0                        max f1   0.495216     0.813665  151.0
# 1                        max f2   0.270072     0.850783  232.0
# 2                  max f0point5   0.611123     0.854254  111.0
# 3                  max accuracy   0.523117     0.958768  141.0
# 4                 max precision   0.984921     1.000000    0.0
# 5                    max recall   0.018326     1.000000  370.0
# 6               max specificity   0.984921     1.000000    0.0
# 7              max absolute_mcc   0.495216     0.791088  151.0
# 8    max min_per_class_accuracy   0.278752     0.928804  229.0
# 9   max mean_per_class_accuracy   0.211268     0.932969  256.0
# 10                      max tns   0.984921  8891.000000    0.0
# 11                      max fns   0.984921  1171.000000    0.0
# 12                      max fps   0.000386  8891.000000  399.0
# 13                      max tps   0.018326  1174.000000  370.0
# 14                      max tnr   0.984921     1.000000    0.0
# 15                      max fnr   0.984921     0.997445    0.0
# 16                      max fpr   0.000386     1.000000  399.0
# 17                      max tpr   0.018326     1.000000  370.0
# Gains/Lift Table: Avg response rate: 11.66 %, avg score: 12.58 %
#     group  cumulative_data_fraction  ...  cumulative_gain  kolmogorov_smirnov
# 0       1                  0.010035  ...       757.325383            0.086031
# 1       2                  0.020070  ...       757.325383            0.172061
# 2       3                  0.030005  ...       754.486558            0.256276
# 3       4                  0.040040  ...       750.943308            0.340378
# 4       5                  0.050075  ...       747.119129            0.423516
# 5       6                  0.100050  ...       651.756021            0.738183
# 6       7                  0.150025  ...       489.340230            0.831069
# 7       8                  0.200000  ...       381.260647            0.863207
# 8       9                  0.300050  ...       232.710381            0.790446
# 9      10                  0.400000  ...       149.787053            0.678262
# 10     11                  0.500050  ...        99.980131            0.565966
# 11     12                  0.600000  ...        66.666667            0.452817
# 12     13                  0.699950  ...        42.867282            0.339669
# 13     14                  0.800000  ...        25.000000            0.226409
# 14     15                  0.899950  ...        11.117244            0.113261
# 15     16                  1.000000  ...         0.000000            0.000000
#
# [16 rows x 14 columns]
# ModelMetricsBinomialGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 0.06124358489484456
# RMSE: 0.2474744126063229
# LogLoss: 0.19340693386964977
# Null degrees of freedom: 33780
# Residual degrees of freedom: 33754
# Null deviance: 24444.710173612573
# Residual deviance: 13066.959266101278
# AIC: 13120.959266101278
# AUC: 0.9375356011573918
# AUCPR: 0.6347716819784154
# Gini: 0.8750712023147835
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.27692080449083484:
#                no     yes   Error               Rate
# 0     no  27253.0  2561.0  0.0859   (2561.0/29814.0)
# 1    yes    923.0  3044.0  0.2327     (923.0/3967.0)
# 2  Total  28176.0  5605.0  0.1031   (3484.0/33781.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0.276921      0.636022  228.0
# 1                        max f2   0.141380      0.744997  287.0
# 2                  max f0point5   0.456646      0.614827  160.0
# 3                  max accuracy   0.467359      0.909713  156.0
# 4                 max precision   0.876205      0.866279   15.0
# 5                    max recall   0.001151      1.000000  397.0
# 6               max specificity   0.986293      0.999966    0.0
# 7              max absolute_mcc   0.235267      0.592419  246.0
# 8    max min_per_class_accuracy   0.157383      0.868887  280.0
# 9   max mean_per_class_accuracy   0.103445      0.874713  307.0
# 10                      max tns   0.986293  29813.000000    0.0
# 11                      max fns   0.986293   3963.000000    0.0
# 12                      max fps   0.000515  29814.000000  399.0
# 13                      max tps   0.001151   3967.000000  397.0
# 14                      max tnr   0.986293      0.999966    0.0
# 15                      max fnr   0.986293      0.998992    0.0
# 16                      max fpr   0.000515      1.000000  399.0
# 17                      max tpr   0.001151      1.000000  397.0
# Gains/Lift Table: Avg response rate: 11.74 %, avg score: 11.75 %
#     group  cumulative_data_fraction  ...  cumulative_gain  kolmogorov_smirnov
# 0       1                  0.010006  ...       618.023173            0.070065
td></tr>
# <tr><td>GBM_grid_1_AutoML_1_20211001_200203_model_8            </td><td style="text-align: right;">0.933681</td><td style="text-align: right;"> 0.199559</td><td style="text-align:

# %%
#look at best model
se = aml.leader
metalearner = h2o.get_model(se.metalearner()['name'])
# Out:
# /usr/local/lib/python3.7/dist-packages/h2o/estimators/stackedensemble.py:929: H2ODeprecationWarning: The usage of stacked_ensemble.metalearner()['name'] will be deprecated. Metalearner now returns the metalearner object. If you need to get the 'name' please use stacked_ensemble.metalearner().model_id
#   H2ODeprecationWarning

# %%
#look at important variables
metalearner.varimp()
# Out:
# [('DRF_1_AutoML_1_20211001_200203',
#   0.5622373223304749,
#   1.0,
#   0.20415031211435622),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_3',
#   0.342052161693573,
#   0.6083768332485757,
#   0.12420032039084038),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_19',
#   0.200171560049057,
#   0.3560268094962915,
#   0.07268298427974636),
#  ('GBM_1_AutoML_1_20211001_200203',
#   0.14429116249084473,
#   0.2566374674181315,
#   0.05239261907364947),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_21',
#   0.12340133637189865,
#   0.21948264811094337,
#   0.044807451115534504),
#  ('GBM_2_AutoML_1_20211001_200203',
#   0.11931068450212479,
#   0.2122069805106174,
#   0.04332212130408765),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_5',
#   0.11813685297966003,
#   0.21011919395529016,
#   0.04289589902718944),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_28',
#   0.10294314473867416,
#   0.18309553750714133,
#   0.03737901112882872),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_31',
#   0.10213633626699448,
#   0.18166054121707742,
#   0.03708605618832923),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_40',
#   0.09701512008905411,
#   0.17255190332603007,
#   0.03522652491993526),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_29',
#   0.09034862369298935,
#   0.16069481712543401,
#   0.03280589707131675),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_25',
#   0.08560346812009811,
#   0.15225504376918908,
#   0.031082914706464917),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_38',
#   0.0830879807472229,
#   0.14778097690637657,
#   0.030169532560001246),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_2',
#   0.08261793106794357,
#   0.14694494261870072,
#   0.02999885589923392),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_30',
#   0.07889822125434875,
#   0.14032903565938218,
#   0.028648216428569497),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_8',
#   0.07450850307941437,
#   0.13252144622946138,
#   0.027054294609590416),
#  ('DeepLearning_grid_1_AutoML_1_20211001_200203_model_3',
#   0.07407276332378387,
#   0.1317464358587084,
#   0.026896076000509337),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_12',
#   0.07260601967573166,
#   0.12913767334900422,
#   0.026363496319920996),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_14',
#   0.052562277764081955,
#   0.09348770648346717,
#   0.019085544457455146),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_57',
#   0.046332914382219315,
#   0.08240810871496274,
#   0.01682364111491344),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_56',
#   0.03684397041797638,
#   0.06553099368298435,
#   0.01337817281354516),
#  ('DeepLearning_grid_1_AutoML_1_20211001_200203_model_2',
#   0.027063241228461266,
#   0.04813490701094704,
#   0.009826756289880353),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_23',
#   0.024414101615548134,
#   0.04342312515709849,
#   0.00886484455380241),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_32',
#   0.012495693750679493,
#   0.022224945328931236,
#   0.004537229525625816),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_1',
#   0.0008846737910062075,
#   0.0015734881977226855,
#   0.0003212281066733421),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_37', 0.0, 0.0, 0.0),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_10', 0.0, 0.0, 0.0),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_7', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_18', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_36', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_46', 0.0, 0.0, 0.0),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_14', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_51', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_11', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_63', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_26', 0.0, 0.0, 0.0),
#  ('GBM_5_AutoML_1_20211001_200203', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_10', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_43', 0.0, 0.0, 0.0),
#  ('XGBoost_3_AutoML_1_20211001_200203', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_24', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_44', 0.0, 0.0, 0.0),
#  ('GBM_3_AutoML_1_20211001_200203', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_5', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_55', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_13', 0.0, 0.0, 0.0),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_4', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_12', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_34', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_27', 0.0, 0.0, 0.0),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_2', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_62', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_52', 0.0, 0.0, 0.0),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_19', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_15', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_58', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_3', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_59', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_39', 0.0, 0.0, 0.0),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_9', 0.0, 0.0, 0.0),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_17', 0.0, 0.0, 0.0),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_1', 0.0, 0.0, 0.0),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_6', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_60', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_45', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_61', 0.0, 0.0, 0.0),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_20', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_6', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_22', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_33', 0.0, 0.0, 0.0),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_18', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_47', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_35', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_64', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_7', 0.0, 0.0, 0.0),
#  ('GBM_4_AutoML_1_20211001_200203', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_4', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_65', 0.0, 0.0, 0.0),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_11', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_20', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_41', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_49', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_53', 0.0, 0.0, 0.0),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_23', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_8', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_42', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_48', 0.0, 0.0, 0.0),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_24', 0.0, 0.0, 0.0),
#  ('XGBoost_2_AutoML_1_20211001_200203', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_50', 0.0, 0.0, 0.0),
#  ('XGBoost_1_AutoML_1_20211001_200203', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_9', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_17', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_21', 0.0, 0.0, 0.0),
#  ('XRT_1_AutoML_1_20211001_200203', 0.0, 0.0, 0.0),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_13', 0.0, 0.0, 0.0),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_16', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_54', 0.0, 0.0, 0.0),
#  ('XGBoost_grid_1_AutoML_1_20211001_200203_model_16', 0.0, 0.0, 0.0),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_22', 0.0, 0.0, 0.0),
#  ('GLM_1_AutoML_1_20211001_200203', 0.0, 0.0, 0.0),
#  ('DeepLearning_grid_1_AutoML_1_20211001_200203_model_1', 0.0, 0.0, 0.0),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_15', 0.0, 0.0, 0.0),
#  ('DeepLearning_1_AutoML_1_20211001_200203', 0.0, 0.0, 0.0),
#  ('DeepLearning_grid_1_AutoML_1_20211001_200203_model_4', 0.0, 0.0, 0.0),
#  ('GBM_grid_1_AutoML_1_20211001_200203_model_25', 0.0, 0.0, 0.0)]

# %%
mc_plot = aml.model_correlation_heatmap(test)

# or if some subset of the models is needed a slice of leaderboard can be used, e.g., using MAE as the sorting metric
mc_plot = h2o.model_correlation_heatmap(aml.leaderboard.sort("rmse").head(10), test)

# or even extended leaderboard can be used
mc_plot = h2o.model_correlation_heatmap(h2o.automl.get_leaderboard(aml, extra_columns="training_time_ms").sort("training_time_ms").head(10), test)

# also more complicated queries on leaderboard can be used, e.g., model correlation between 5 fastest models to train and Stacked Ensembles
leaderboard = h2o.automl.get_leaderboard(aml, extra_columns="training_time_ms").sort("training_time_ms")
mc_plot = h2o.model_correlation_heatmap(leaderboard.head(5).rbind(leaderboard[leaderboard["model_id"].grep("StackedEnsemble", output_logical=True)]), test)

# %%
va_plot = aml.varimp_heatmap()

# or if some subset of the models is needed a slice of leaderboard can be used, e.g., using MAE as the sorting metric
va_plot = h2o.varimp_heatmap(aml.leaderboard.sort("rmse").head(10))

# or even extended leaderboard can be used
va_plot = h2o.varimp_heatmap(h2o.automl.get_leaderboard(aml, extra_columns="training_time_ms").sort("training_time_ms").head(10))

# %%
#explain a single H2O model (e.g. leader model from AutoML)
exm = aml.leader.explain(test)
# Out:
# # Confusion Matrix
# > Confusion matrix shows a predicted class vs an actual class.
# ## StackedEnsemble_AllModels_3_AutoML_1_20211001_200203
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.323025763217983:
#               no     yes   Error               Rate
# 0     no  9335.0   773.0  0.0765    (773.0/10108.0)
# 1    yes   352.0   970.0  0.2663     (352.0/1322.0)
# 2  Total  9687.0  1743.0  0.0984   (1125.0/11430.0)
# # Partial Dependence Plots
# > Partial dependence plot (PDP) gives a graphical depiction of the marginal effect of a variable on the response. The effect of a variable is measured in change in the mean response. PDP assumes independence between the feature for which is the PDP computed and the rest.

# %% [markdown]
# # Base Learner Model Exploration

# %%
#import top performing base learner
base_model = h2o.get_model('DRF_1_AutoML_1_20211001_200203')

# %%
#evaluate the base learner on the test set
base_model.model_performance(test)
# Out:
# ModelMetricsBinomial: drf
# ** Reported on test data. **
#
# MSE: 0.0801189329540104
# RMSE: 0.28305288013728175
# LogLoss: 0.2670812405835223
# Mean Per-Class Error: 0.1303526303217235
# AUC: 0.9281288558604888
# AUCPR: 0.5868022283491746
# Gini: 0.8562577117209775
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.08806422752426132:
#               no     yes   Error               Rate
# 0     no  9204.0   904.0  0.0894    (904.0/10108.0)
# 1    yes   342.0   980.0  0.2587     (342.0/1322.0)
# 2  Total  9546.0  1884.0   0.109   (1246.0/11430.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0.088064      0.611354  275.0
# 1                        max f2   0.039427      0.734712  327.0
# 2                  max f0point5   0.166274      0.586690  209.0
# 3                  max accuracy   0.166274      0.905599  209.0
# 4                 max precision   1.000000      1.000000    0.0
# 5                    max recall   0.000009      1.000000  399.0
# 6               max specificity   1.000000      1.000000    0.0
# 7              max absolute_mcc   0.060850      0.563087  301.0
# 8    max min_per_class_accuracy   0.050110      0.862330  314.0
# 9   max mean_per_class_accuracy   0.039427      0.869647  327.0
# 10                      max tns   1.000000  10108.000000    0.0
# 11                      max fns   1.000000   1320.000000    0.0
# 12                      max fps   0.000009  10108.000000  399.0
# 13                      max tps   0.000009   1322.000000  399.0
# 14                      max tnr   1.000000      1.000000    0.0
# 15                      max fnr   1.000000      0.998487    0.0
# 16                      max fpr   0.000009      1.000000  399.0
# 17                      max tpr   0.000009      1.000000  399.0
# Gains/Lift Table: Avg response rate: 11.57 %, avg score:  4.78 %
#     group  cumulative_data_fraction  ...  cumulative_gain  kolmogorov_smirnov
# 0       1                  0.010061  ...       561.606262            0.063895
# 1       2                  0.020035  ...       538.066579            0.121901
# 2       3                  0.030009  ...       512.529386            0.173919
# 3       4                  0.040070  ...       479.545680            0.217285
# 4       5                  0.050044  ...       465.314791            0.263316
# 5       6                  0.100000  ...       420.423601            0.475410
# 6       7                  0.150044  ...       362.799981            0.615554
# 7       8                  0.200000  ...       311.497731            0.704475
# 8       9                  0.300000  ...       214.674735            0.728255
# 9      10                  0.404024  ...       142.080257            0.649116
# 10     11                  0.500000  ...        98.184569            0.555129
# 11     12                  0.600000  ...        65.532022            0.444617
# 12     13                  0.700262  ...        42.155473            0.333807
# 13     14                  1.000000  ...         0.000000            0.000000
#
# [14 rows x 14 columns]

# %%
#look at important variable
base_model.varimp_plot(num_of_features=20)

# %%
learning_curve_plot = base_model.learning_curve_plot()

# %% [markdown]
# ## Base Learner Model Explainability

# %%
#explain a model
base_exm = base_model.explain(test)
# Out:
# # Confusion Matrix
# > Confusion matrix shows a predicted class vs an actual class.
# ## DRF_1_AutoML_1_20211001_200203
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.08806422752426132:
#               no     yes   Error               Rate
# 0     no  9204.0   904.0  0.0894    (904.0/10108.0)
# 1    yes   342.0   980.0  0.2587     (342.0/1322.0)
# 2  Total  9546.0  1884.0   0.109   (1246.0/11430.0)
# # Variable Importance
# > The variable importance plot shows the relative importance of the most important variables in the model.
# # SHAP Summary
# > SHAP summary plot shows the contribution of the features for each instance (row of data). The sum of the feature contributions and the bias term is equal to the raw prediction of the model, i.e., prediction before applying inverse link function.
# # Partial Dependence Plots
# > Partial dependence plot (PDP) gives a graphical depiction of the marginal effect of a variable on the response. The effect of a variable is measured in change in the mean response. PDP assumes independence between the feature for which is the PDP computed and the rest.
